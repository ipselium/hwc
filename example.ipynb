# %%
from hwc import Distribute

d = Distribute('datasets/choices2021.json', pmin=3)
d.display_optimal_possibilities()
# Out:
# 7821 possibilities found.
# 5 best choices:
#    BEAUFILS/LEGO  BERTRAND/BODIN  BIFFAUD/VALOGNES  BOURGEOIS/PINCEMIN  \
# 0              3              10                15                   5
# 1              3              10                15                   5
# 2              3              10                15                   5
# 3              3              10                15                   5
# 4              3              10                15                   5
#
#    BUTTARD  CHOTTIN  DELOCHE/RABASSE  DUFOUR/MAZELLIER  PERIN  POIRIER/VERDU  \
# 0       22       24               17                14     12              9
# 1       22       24               17                14     12              1
# 2       22       24               17                21     14              9
# 3       22       24               17                21     14              1
# 4       22       24               17                21     14              1
#
#    TOUSSAINT  VERNEDE  YAHIAOUI  ZHANG
# 0         19        8        13      1
# 1         19        8        13      9
# 2         19        8        13      1
# 3         19        8         9     12
# 4         19        8        13      9
